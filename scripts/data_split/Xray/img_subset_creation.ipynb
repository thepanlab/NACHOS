# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os,sys
sys.path.insert(0,"..")
from glob import glob
import matplotlib.pyplot as plt
import shutil
import numpy as np
import pandas as pd
import pathlib
import torch
import torchvision
import torchxrayvision as xrv
import ast
import re
import skimage
from PIL import Image

# %% [markdown]
# Helper functions for creating the image subsets:
#
# move_matching:
#     df - first collumn is unique id labelled ['id']
#     dest - Destination directory to move files
#     source - source directory
#
# rename_matching:
#     df - first collumn is ['id'] and second is ['file_dir'] which points to the location of the files such that path/file_dir points to the file
#     path - base folder for all data
#
#
#     dataset - label for dataset
#     subset - label for subset
#     view - label for view
#     Note: they are just labels for the renaming and are not computed in any other way

# %%
import os
import pathlib
import shutil
from tqdm import tqdm

def rename_and_copy_files(df, source, dataset, subset, view, dest, default_file_type=".png", file_types=(".jpg", ".png")):
    pl_path = pathlib.Path(source)
    pl_dest = pathlib.Path(dest)
    pl_dest.mkdir(parents=True, exist_ok=True)
    renamed_files = []
    overlaps = []  # To store any overlaps

    for index, row in tqdm(df.iterrows(), total=df.shape[0], desc="Processing files"):
        uid = row['patientid']
        sub_path = row['file_dir']
        img_sub_path = pl_path.joinpath(sub_path)

        for file in img_sub_path.iterdir():
            if file.suffix in file_types:
                newName = f"{index}_{dataset}_{subset}_{view}_{uid}{file.suffix}"
                newPath = pl_dest / newName
                if not newPath.exists():
                    shutil.copy(file, newPath)
                    renamed_files.append(newPath)
                else:
                    overlaps.append(newPath)
    return renamed_files, overlaps  # Return both the list of renamed/copied files and the overlaps


def copy_files(file_paths, dest):
    pl_dest = pathlib.Path(dest)
    pl_dest.mkdir(parents=True, exist_ok=True)

    error_files = []

    for file_path in tqdm(file_paths, desc="Copying files"):
        try:
            destination_path = pl_dest / file_path.name
            if not destination_path.exists():
                shutil.copy(file_path, destination_path)
            else:
                error_files.append((file_path, "File already exists in destination."))
        except Exception as e:
            error_files.append((file_path, str(e)))

    return error_files

def create_subset(df, dest, source, dataset, subset, view, file_types=(".jpg", ".png")):
    renamed_files, overlaps = rename_and_copy_files(df, source, dataset, subset, view, dest, default_file_type=file_types[0], file_types=file_types)
    # If you want to print the overlaps:
    for overlap_msg in overlaps:
        print(overlap_msg)

    error_files = copy_files(renamed_files, dest)

    if error_files:
        print("Files that encountered errors during the copy operation:")
        for file, error in error_files:
            print(f"File: {file}, Error: {error}")

# %%
d_padchest = xrv.datasets.PC_Dataset(imgpath="/ssd2/averijordan/PADCHEST_SJ/image_zips", csvpath="/ssd2/averijordan/PADCHEST_SJ/labels_csv/PADCHEST_chest_x_ray_images_labels_160K_01.02.19.csv", views = ["PA", "AP"], unique_patients=False)

# %%
#Load mimic data
#CSV Paths
metadata_path = "/ssd2/jpmokc/datasets/physionet.org/files/mimic-cxr-jpg/2.0.0/mimic-cxr-2.0.0-metadata.csv.gz"
cheXpert_path = "/ssd2/jpmokc/datasets/physionet.org/files/mimic-cxr-jpg/2.0.0/mimic-cxr-2.0.0-chexpert.csv.gz"

d_mimic = xrv.datasets.MIMIC_Dataset(imgpath="/", csvpath=cheXpert_path, metacsvpath=metadata_path, views=['AP', 'PA'], unique_patients=False)

# %%
print(d_padchest.csv.columns)
print(d_mimic.csv.columns)
# Out:
# Index(['Unnamed: 0', 'ImageID', 'ImageDir', 'StudyDate_DICOM', 'StudyID',
#        'PatientID', 'PatientBirth', 'PatientSex_DICOM', 'ViewPosition_DICOM',
#        'Projection', 'MethodProjection', 'Pediatric', 'Modality_DICOM',
#        'Manufacturer_DICOM', 'PhotometricInterpretation_DICOM',
#        'PixelRepresentation_DICOM', 'PixelAspectRatio_DICOM',
#        'SpatialResolution_DICOM', 'BitsStored_DICOM', 'WindowCenter_DICOM',
#        'WindowWidth_DICOM', 'Rows_DICOM', 'Columns_DICOM',
#        'XRayTubeCurrent_DICOM', 'Exposure_DICOM', 'ExposureInuAs_DICOM',
#        'ExposureTime', 'RelativeXRayExposure_DICOM', 'ReportID', 'Report',
#        'MethodLabel', 'Labels', 'Localizations',
#        'LabelsLocalizationsBySentence', 'labelCUIS', 'LocalizationsCUIS',
#        'view', 'offset_day_int', 'patientid', 'age_years', 'sex_male',
#        'sex_female'],
#       dtype='object')
# Index(['subject_id', 'study_id', 'Atelectasis', 'Cardiomegaly',
#        'Consolidation', 'Edema', 'Enlarged Cardiomediastinum', 'Fracture',
#        'Lung Lesion', 'Lung Opacity', 'No Finding', 'Pleural Effusion',
#        'Pleural Other', 'Pneumonia', 'Pneumothorax', 'Support Devices',
#        'dicom_id', 'PerformedProcedureStepDescription', 'ViewPosition', 'Rows',
#        'Columns', 'StudyDate', 'StudyTime',
#        'ProcedureCodeSequence_CodeMeaning', 'ViewCodeSequence_CodeMeaning',
#        'PatientOrientationCodeSequence_CodeMeaning', 'view', 'offset_day_int',
#        'patientid'],
#       dtype='object')

# %%
#Create csv subset
cols = ['Cardiomegaly','No Finding', 'Pleural Effusion',"Pneumonia",'ProcedureCodeSequence_CodeMeaning', 'subject_id', 'study_id', 'dicom_id', 'patientid']
d_mimic_sub = d_mimic.csv[cols].copy()

#Add file directories collumn
d_mimic_sub['file_dir'] = "p" + d_mimic_sub['subject_id'].astype(str).str[:2] + "/p" + d_mimic_sub['subject_id'].astype(str) + "/s" + d_mimic_sub['study_id'].astype(str) + "/"

# %%
d_mimic_sub
# Out:
#         Cardiomegaly  No Finding  Pleural Effusion  Pneumonia  \
# 0                0.0         1.0               0.0        0.0
# 2                0.0         1.0               0.0        0.0
# 4                0.0         1.0               0.0        0.0
# 5                0.0         1.0               0.0        0.0
# 6                0.0         1.0               0.0        0.0
# ...              ...         ...               ...        ...
# 377089           0.0         1.0               0.0        0.0
# 377090           0.0         1.0               0.0        0.0
# 377092          -1.0         NaN               0.0        NaN
# 377093           NaN         NaN               NaN        NaN
# 377094           NaN         NaN               NaN        NaN
#
#        ProcedureCodeSequence_CodeMeaning  subject_id  study_id  \
# 0                     CHEST (PA AND LAT)    10000032  50414267
# 2                     CHEST (PA AND LAT)    10000032  53189527
# 4                    CHEST (PORTABLE AP)    10000032  53911762
# 5                    CHEST (PORTABLE AP)    10000032  53911762
# 6                    CHEST (PORTABLE AP)    10000032  56699142
# ...                                  ...         ...       ...
# 377089                CHEST (PA AND LAT)    19999733  57132437
# 377090                CHEST (PA AND LAT)    19999733  57132437
# 377092               CHEST (PORTABLE AP)    19999987  55368167
# 377093               CHEST (PORTABLE AP)    19999987  58621812
# 377094               CHEST (PORTABLE AP)    19999987  58971208
#
#                                             dicom_id patientid  \
# 0       02aa804e-bde0afdd-112c0b34-7bc16630-4e384014  10000032
# 2       2a2277a9-b0ded155-c0de8eb9-c124d10e-82c5caab  10000032
# 4       68b5c4b1-227d0485-9cc38c3f-7b84ab51-4b472714  10000032
# 5       fffabebf-74fd3a1f-673b6b41-96ec0ac9-2ab69818  10000032
# 6       ea030e7a-2e3b1346-bc518786-7a8fd698-f673b44c  10000032
# ...                                              ...       ...
# 377089  3fcd0406-9b111603-feae7033-96632b3a-111333e5  19999733
# 377090  428e2c18-5721d8f3-35a05001-36f3d080-9053b83c  19999733
# 377092  58766883-376a15ce-3b323a28-6af950a0-16b793bd  19999987
# 377093  7ba273af-3d290f8d-e28d0ab4-484b7a86-7fc12b08  19999987
# 377094  1a1fe7e3-cbac5d93-b339aeda-86bb86b5-4f31e82e  19999987
#
#                         file_dir
# 0       p10/p10000032/s50414267/
# 2       p10/p10000032/s53189527/
# 4       p10/p10000032/s53911762/
# 5       p10/p10000032/s53911762/
# 6       p10/p10000032/s56699142/
# ...                          ...
# 377089  p19/p19999733/s57132437/
# 377090  p19/p19999733/s57132437/
# 377092  p19/p19999987/s55368167/
# 377093  p19/p19999987/s58621812/
# 377094  p19/p19999987/s58971208/
#
# [243324 rows x 10 columns]

# %%
allowed_ap_views = {'CHEST (PORTABLE AP)',  'CHEST (SINGLE VIEW)'}
allowed_pa_views = {'CHEST (PA AND LAT)'}


d_mimic_ap = d_mimic_sub[d_mimic_sub['ProcedureCodeSequence_CodeMeaning'].isin(allowed_ap_views)]
d_mimic_pa = d_mimic_sub[d_mimic_sub['ProcedureCodeSequence_CodeMeaning'].isin(allowed_pa_views)]

#Create filter for count of labels assignmed
exclusive_filter = d_mimic_sub[['Cardiomegaly','No Finding', 'Pleural Effusion', 'Pneumonia']].sum(axis=1)
binary_filter = d_mimic_sub[['Cardiomegaly','No Finding']].sum(axis=1)

#Apply filter so that only entries with one label are left
d_mimic_ap = d_mimic_ap[binary_filter == 1]
d_mimic_pa = d_mimic_pa[binary_filter == 1]

# %%
d_mimic_cardiomegaly_ap = d_mimic_ap[d_mimic_ap['Cardiomegaly'] == 1.0]
d_mimic_no_finding_ap  = d_mimic_ap[d_mimic_ap['No Finding'] == 1.0]

d_mimic_cardiomegaly_pa  = d_mimic_pa[d_mimic_pa['Cardiomegaly'] == 1.0]
d_mimic_no_finding_pa       = d_mimic_pa[d_mimic_pa['No Finding'] == 1.0]

# %%
d_mimic_cardiomegaly_ap_file_info  = d_mimic_cardiomegaly_ap[["patientid", "file_dir"]].copy()
d_mimic_cardiomegaly_pa_file_info  = d_mimic_cardiomegaly_pa[["patientid", "file_dir"]].copy()

d_mimic_no_finding_ap_file_info = d_mimic_no_finding_ap[["patientid", "file_dir"]].copy()
d_mimic_no_finding_pa_file_info = d_mimic_no_finding_pa[["patientid", "file_dir"]].copy()

# %%
totals = d_padchest.totals()
pathologies = []
for p in totals:
    pathologies.append(p)

pathologies.append('Normal')
pathologies.append('pleural effusion')

# %%
pathologies
# Out:
# ['Air Trapping',
#  'Aortic Atheromatosis',
#  'Aortic Elongation',
#  'Atelectasis',
#  'Bronchiectasis',
#  'Cardiomegaly',
#  'Consolidation',
#  'Costophrenic Angle Blunting',
#  'Edema',
#  'Effusion',
#  'Emphysema',
#  'Fibrosis',
#  'Flattened Diaphragm',
#  'Fracture',
#  'Granuloma',
#  'Hemidiaphragm Elevation',
#  'Hernia',
#  'Hilar Enlargement',
#  'Infiltration',
#  'Mass',
#  'Nodule',
#  'Pleural_Thickening',
#  'Pneumonia',
#  'Pneumothorax',
#  'Scoliosis',
#  'Support Devices',
#  'Tube',
#  'Tuberculosis',
#  'normal',
#  'pleural effusion']

# %%
#Seperate Collumns we want
d_labelData = pd.concat([d_padchest.csv["Labels"],d_padchest.csv["LabelsLocalizationsBySentence"], d_padchest.csv["patientid"], d_padchest.csv["StudyID"], d_padchest.csv["Projection"], d_padchest.csv["ImageID"], d_padchest.csv["ImageDir"]], axis=1)

#Seperate out the bundled inner arrays 
d_labelData["Labels"] = d_labelData["Labels"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

d_labelData = d_labelData[d_labelData["Labels"].apply(lambda x: any(label.lower() in [s.lower() for s in x] for label in pathologies))]

#Create Collum for file directories (used in above function)
d_labelData["file_dir"] = "images-" + d_labelData["ImageDir"].astype(str) + "/"

#Chop off the .jpg
d_labelData['ImageID'] = d_labelData['ImageID'].apply(lambda x: x[:-4])
# Out:
# {'Atelectasis': {0.0: 82269, 1.0: 48790},
#  'Cardiomegaly': {0.0: 92752, 1.0: 47673},
#  'Consolidation': {0.0: 88179, 1.0: 11525},
#  'Edema': {0.0: 101747, 1.0: 29331},
#  'Effusion': {0.0: 102492, 1.0: 57721},
#  'Enlarged Cardiomediastinum': {0.0: 84746, 1.0: 7657},
#  'Fracture': {0.0: 81584, 1.0: 4781},
#  'Lung Lesion': {0.0: 81685, 1.0: 6632},
#  'Lung Opacity': {0.0: 83336, 1.0: 54769},
#  'Pleural Other': {0.0: 81202, 1.0: 2083},
#  'Pneumonia': {0.0: 96223, 1.0: 17222},
#  'Pneumothorax': {0.0: 120294, 1.0: 11235},
#  'Support Devices': {0.0: 84023, 1.0: 61717}}
# {'Air Trapping': {0.0: 91429, 1.0: 3396},
#  'Aortic Atheromatosis': {0.0: 93193, 1.0: 1632},
#  'Aortic Elongation': {0.0: 87071, 1.0: 7754},
#  'Atelectasis': {0.0: 90480, 1.0: 4345},
#  'Bronchiectasis': {0.0: 93314, 1.0: 1511},
#  'Cardiomegaly': {0.0: 86081, 1.0: 8744},
#  'Consolidation': {0.0: 93729, 1.0: 1096},
#  'Costophrenic Angle Blunting': {0.0: 91234, 1.0: 3591},
#  'Edema': {0.0: 94366, 1.0: 459},
#  'Effusion': {0.0: 90887, 1.0: 3938},
#  'Emphysema': {0.0: 93867, 1.0: 958},
#  'Fibrosis': {0.0: 94142, 1.0: 683},
#  'Flattened Diaphragm': {0.0: 94291, 1.0: 534},
#  'Fracture': {0.0: 92130, 1.0: 2695},
#  'Granuloma': {0.0: 92347, 1.0: 2478},
#  'Hemidiaphragm Elevation': {0.0: 93409, 1.0: 1416},
#  'Hernia': {0.0: 93296, 1.0: 1529},
#  'Hilar Enlargement': {0.0: 90581, 1.0: 4244},
#  'Infiltration': {0.0: 86096, 1.0: 8729},
#  'Mass': {0.0: 93999, 1.0: 826},
#  'Nodule': {0.0: 91065, 1.0: 3760},
#  'Pleural_Thickening': {0.0: 91589, 1.0: 3236},
#  'Pneumonia': {0.0: 91243, 1.0: 3582},
#  'Pneumothorax': {0.0: 94582, 1.0: 243},
#  'Scoliosis': {0.0: 89383, 1.0: 5442},
#  'Support Devices': {0.0: 93044, 1.0: 1781},
#  'Tube': {0.0: 93233, 1.0: 1592},
#  'Tuberculosis': {0.0: 94081, 1.0: 744}}
# {'Atelectasis': {0.0: 82269, 1.0: 48790},
#  'Cardiomegaly': {0.0: 92752, 1.0: 47673},
#  'Consolidation': {0.0: 88179, 1.0: 11525},
#  'Edema': {0.0: 101747, 1.0: 29331},
#  'Effusion': {0.0: 102492, 1.0: 57721},
#  'Enlarged Cardiomediastinum': {0.0: 84746, 1.0: 7657},
#  'Fracture': {0.0: 81584, 1.0: 4781},
#  'Lung Lesion': {0.0: 81685, 1.0: 6632},
#  'Lung Opacity': {0.0: 83336, 1.0: 54769},
#  'Pleural Other': {0.0: 81202, 1.0: 2083},
#  'Pneumonia': {0.0: 96223, 1.0: 17222},
#  'Pneumothorax': {0.0: 120294, 1.0: 11235},
#  'Support Devices': {0.0: 84023, 1.0: 61717}}
# {'Air Trapping': {0.0: 91429, 1.0: 3396},
#  'Aortic Atheromatosis': {0.0: 93193, 1.0: 1632},
#  'Aortic Elongation': {0.0: 87071, 1.0: 7754},
#  'Atelectasis': {0.0: 90480, 1.0: 4345},
#  'Bronchiectasis': {0.0: 93314, 1.0: 1511},
#  'Cardiomegaly': {0.0: 86081, 1.0: 8744},
#  'Consolidation': {0.0: 93729, 1.0: 1096},
#  'Costophrenic Angle Blunting': {0.0: 91234, 1.0: 3591},
#  'Edema': {0.0: 94366, 1.0: 459},
#  'Effusion': {0.0: 90887, 1.0: 3938},
#  'Emphysema': {0.0: 93867, 1.0: 958},
#  'Fibrosis': {0.0: 94142, 1.0: 683},
#  'Flattened Diaphragm': {0.0: 94291, 1.0: 534},
#  'Fracture': {0.0: 92130, 1.0: 2695},
#  'Granuloma': {0.0: 92347, 1.0: 2478},
#  'Hemidiaphragm Elevation': {0.0: 93409, 1.0: 1416},
#  'Hernia': {0.0: 93296, 1.0: 1529},
#  'Hilar Enlargement': {0.0: 90581, 1.0: 4244},
#  'Infiltration': {0.0: 86096, 1.0: 8729},
#  'Mass': {0.0: 93999, 1.0: 826},
#  'Nodule': {0.0: 91065, 1.0: 3760},
#  'Pleural_Thickening': {0.0: 91589, 1.0: 3236},
#  'Pneumonia': {0.0: 91243, 1.0: 3582},
#  'Pneumothorax': {0.0: 94582, 1.0: 243},
#  'Scoliosis': {0.0: 89383, 1.0: 5442},
#  'Support Devices': {0.0: 93044, 1.0: 1781},
#  'Tube': {0.0: 93233, 1.0: 1592},
#  'Tuberculosis': {0.0: 94081, 1.0: 744}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 2
#       1 #Seperate Collumns we want
# ----> 2 d_labelData = pd.concat([d_padchest.csv["Labels"],d_padchest.csv["LabelsLocalizationsBySentence"], d_padchest.csv["patientid"], d_padchest.csv["StudyID"], d_padchest.csv["Projection"], d_padchest.csv["ImageID"], d_padchest.csv["ImageDir"]], axis=1)
#       4 #Seperate out the bundled inner arrays
#       5 d_labelData["Labels"] = d_labelData["Labels"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
#
# Cell In[28], line 2
#       1 #Seperate Collumns we want
# ----> 2 d_labelData = pd.concat([d_padchest.csv["Labels"],d_padchest.csv["LabelsLocalizationsBySentence"], d_padchest.csv["patientid"], d_padchest.csv["StudyID"], d_padchest.csv["Projection"], d_padchest.csv["ImageID"], d_padchest.csv["ImageDir"]], axis=1)
#       4 #Seperate out the bundled inner arrays
#       5 d_labelData["Labels"] = d_labelData["Labels"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)
#
# File _pydevd_bundle/pydevd_cython.pyx:1457, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:701, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1152, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1135, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:312, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~/miniconda3/envs/xray/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd.py:2070, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2067             from_this_thread.append(frame_custom_thread_id)
#    2069     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2070         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2072 frames_list = None
#    2074 if keep_suspended:
#    2075     # This means that we should pause again after a set next statement.
#
# File ~/miniconda3/envs/xray/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd.py:2106, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2103         self._call_input_hook()
#    2105     self.process_internal_commands()
# -> 2106     time.sleep(0.01)
#    2108 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2110 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
#Seperate Collumns we want
d_labelData = pd.concat([d_padchest.csv["Labels"],d_padchest.csv["LabelsLocalizationsBySentence"], d_padchest.csv["patientid"], d_padchest.csv["StudyID"], d_padchest.csv["Projection"], d_padchest.csv["ImageID"], d_padchest.csv["ImageDir"]], axis=1)

#Seperate out the bundled inner arrays 
d_labelData["Labels"] = d_labelData["Labels"].apply(lambda x: ast.literal_eval(x) if isinstance(x, str) else x)

d_labelData = d_labelData[d_labelData["Labels"].apply(lambda x: any(label.lower() in [s.lower() for s in x] for label in pathologies))]

#Create Collum for file directories (used in above function)
d_labelData["file_dir"] = "images-" + d_labelData["ImageDir"].astype(str) + "/"

#Chop off the .jpg
d_labelData['ImageID'] = d_labelData['ImageID'].apply(lambda x: x[:-4])

# %%
# Create label subset for pad_chest

# For cardiomegaly, ensure that 'normal' is not present
d_padchest_cardiomegaly= d_labelData[d_labelData["Labels"].apply(lambda x: ('cardiomegaly' in x) and ('normal' not in x))]

# For normal, ensure that 'cardiomegaly' is not present
d_padchest_no_finding = d_labelData[d_labelData["Labels"].apply(lambda x: ('normal' in x) and ('pleural Cardiomegaly_' not in x))]

# %%
d_padchest_no_finding["Labels"] = d_padchest_no_finding["Labels"].apply(lambda labels_list: ["No-Finding" if label == "normal" else label for label in labels_list])

# %%
d_padchest_cardiomegaly["Labels"] = d_padchest_cardiomegaly["Labels"].apply(lambda labels_list: [label.title() for label in labels_list])
d_padchest_cardiomegaly

# %%
#Seperate out views

d_padchest_cardiomegaly_ap = d_padchest_cardiomegaly[d_padchest_cardiomegaly['Projection'] == "AP"]
d_padchest_cardiomegaly_pa = d_padchest_cardiomegaly[d_padchest_cardiomegaly['Projection'] == "PA"]

d_padchest_no_finding_ap = d_padchest_no_finding[d_padchest_no_finding['Projection'] == "AP"]
d_padchest_no_finding_pa = d_padchest_no_finding[d_padchest_no_finding['Projection'] == "PA"]

# %%
d_padchest_cardiomegaly_ap_file_info = d_padchest_cardiomegaly_ap[["patientid", "ImageID", "file_dir"]].copy()
d_padchest_cardiomegaly_pa_file_info = d_padchest_cardiomegaly_pa[["patientid","ImageID", "file_dir"]].copy()

d_padchest_no_finding_ap_file_info = d_padchest_no_finding_ap[["patientid", "ImageID", "file_dir"]].copy()
d_padchest_no_finding_pa_file_info = d_padchest_no_finding_pa[["patientid", "ImageID", "file_dir"]].copy()

# %%
d_padchest_cardiomegaly_ap_file_info.reset_index(drop=True, inplace = True)
d_padchest_cardiomegaly_pa_file_info.reset_index(drop=True, inplace = True)

d_padchest_no_finding_ap_file_info.reset_index(drop=True, inplace = True)
d_padchest_no_finding_pa_file_info.reset_index(drop=True, inplace = True)

d_mimic_cardiomegaly_ap_file_info.reset_index(drop=True, inplace = True)
d_mimic_cardiomegaly_pa_file_info.reset_index(drop=True, inplace = True)

d_mimic_no_finding_ap_file_info.reset_index(drop=True, inplace = True)
d_mimic_no_finding_pa_file_info.reset_index(drop=True, inplace = True)

# %%
#Move every to csvs for later use

d_padchest_cardiomegaly_ap_file_info.to_csv("d_padchest_cardiomegaly_ap.csv")
d_padchest_cardiomegaly_pa_file_info.to_csv("d_padchest_cardiomegaly_pa.csv")

d_padchest_no_finding_ap_file_info.to_csv("d_padchest_no_finding_ap.csv")
d_padchest_no_finding_pa_file_info.to_csv("d_padchest_no_finding_pa.csv")

d_mimic_cardiomegaly_ap_file_info.to_csv("d_mimic_cardiomegaly_ap.csv")    
d_mimic_cardiomegaly_pa_file_info.to_csv("d_mimic_cardiomegaly_pa.csv")    

d_mimic_no_finding_ap_file_info.to_csv("d_mimic_no_finding_ap.csv")
d_mimic_no_finding_pa_file_info.to_csv("d_mimic_no_finding_pa.csv")

# %%
src_path_mimic = "/ssd2/jpmokc/datasets/physionet.org/files/mimic-cxr-jpg/2.0.0/files/"
src_path_pad = "/ssd2/averijordan/PADCHEST_SJ/image_zips/"
dest_path = "/ssd2/averijordan/datasets/"

# %%
datasets = {

    # PadChest datasets
    "d_padchest_cardiomegaly_ap": {
        "data": d_padchest_cardiomegaly_ap,
        "file_info": d_padchest_cardiomegaly_ap_file_info,
        "dataset_name": "PadChest",
    },
    "d_padchest_cardiomegaly_pa": {
        "data": d_padchest_cardiomegaly_pa,
        "file_info": d_padchest_cardiomegaly_pa_file_info,
        "dataset_name": "PadChest",
    },
    "d_padchest_no_finding_ap": {
        "data": d_padchest_no_finding_ap,
        "file_info": d_padchest_no_finding_ap_file_info,
        "dataset_name": "PadChest",
    },
    "d_padchest_no_finding_pa": {
        "data": d_padchest_no_finding_pa,
        "file_info": d_padchest_no_finding_pa_file_info,
        "dataset_name": "PadChest",
    },

    # MIMIC datasets
    "d_mimic_cardiomegaly_ap": {
        "data": d_mimic_cardiomegaly_ap,
        "file_info": d_mimic_cardiomegaly_ap_file_info,
        "dataset_name": "MIMIC",
    },
    "d_mimic_cardiomegaly_pa": {
        "data": d_mimic_cardiomegaly_pa,
        "file_info": d_mimic_cardiomegaly_pa_file_info,
        "dataset_name": "MIMIC",
    },
    "d_mimic_no_finding_ap": {
        "data": d_mimic_no_finding_ap,
        "file_info": d_mimic_no_finding_ap_file_info,
        "dataset_name": "MIMIC",
    },
    "d_mimic_no_finding_pa": {
        "data": d_mimic_no_finding_pa,
        "file_info": d_mimic_no_finding_pa_file_info,
        "dataset_name": "MIMIC",
    },
}

# %%
def sample_dataframes(data, file_info, sample_size=1000, random_state=100):
    # Reset the indices for both dataframes
    data.reset_index(drop=True, inplace=True)
    file_info.reset_index(drop=True, inplace=True)
    
    n_samples = min(sample_size, len(data))
    
    # Get the indices of the sampled data
    sampled_indices = data.sample(n=n_samples, random_state=random_state).index
    
    # Update the data and file_info using the sampled indices in place
    for df in [data, file_info]:
        drop_indices = set(df.index) - set(sampled_indices)
        df.drop(drop_indices, inplace=True)
for key, dataset_info in datasets.items():
    sample_dataframes(dataset_info['data'], dataset_info['file_info'], sample_size=430,random_state=50)
    print(f"Sampled dataset {key}. New length: {len(dataset_info['data'])} , {len(dataset_info['file_info'])}")

# %%
d_mimic_cardiomegaly_ap

# %%
create_subset(d_padchest_cardiomegaly_ap_file_info, dest_path+"/PadChest/Cardiomegaly/AP",src_path_pad,"PadChest", "Cardiomegaly", "AP", ".png")
create_subset(d_padchest_no_finding_ap_file_info, dest_path+"/PadChest/No-Finding/AP",src_path_pad,"PadChest", "No-Finding", "AP", ".png")

# %%
create_subset(d_mimic_cardiomegaly_ap_file_info, dest_path+"/MIMIC/Cardiomegaly/AP",src_path_mimic,"MIMIC", "Cardiomegaly", "AP", ".jpg")
create_subset(d_mimic_no_finding_ap_file_info, dest_path+"/MIMIC/No-Finding/AP",src_path_mimic,"MIMIC", "No-Finding", "AP", ".jpg")
# Out:
# Processing files: 100%|██████████| 430/430 [00:01<00:00, 290.24it/s]
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/260_MIMIC_Cardiomegaly_AP_10073847.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/422_MIMIC_Cardiomegaly_AP_10147087.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/422_MIMIC_Cardiomegaly_AP_10147087.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/422_MIMIC_Cardiomegaly_AP_10147087.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/422_MIMIC_Cardiomegaly_AP_10147087.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/422_MIMIC_Cardiomegaly_AP_10147087.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/704_MIMIC_Cardiomegaly_AP_10216556.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/900_MIMIC_Cardiomegaly_AP_10268877.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1176_MIMIC_Cardiomegaly_AP_10337761.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2458_MIMIC_Cardiomegaly_AP_10712217.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2458_MIMIC_Cardiomegaly_AP_10712217.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2522_MIMIC_Cardiomegaly_AP_10723086.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2978_MIMIC_Cardiomegaly_AP_10896351.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3121_MIMIC_Cardiomegaly_AP_10922531.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3873_MIMIC_Cardiomegaly_AP_11151295.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4050_MIMIC_Cardiomegaly_AP_11201441.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4355_MIMIC_Cardiomegaly_AP_11276636.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4638_MIMIC_Cardiomegaly_AP_11345335.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4944_MIMIC_Cardiomegaly_AP_11441946.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4985_MIMIC_Cardiomegaly_AP_11451979.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5239_MIMIC_Cardiomegaly_AP_11532890.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5329_MIMIC_Cardiomegaly_AP_11553956.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6237_MIMIC_Cardiomegaly_AP_11798500.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6469_MIMIC_Cardiomegaly_AP_11861017.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7278_MIMIC_Cardiomegaly_AP_12043836.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7318_MIMIC_Cardiomegaly_AP_12045761.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7390_MIMIC_Cardiomegaly_AP_12065121.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7590_MIMIC_Cardiomegaly_AP_12128253.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7875_MIMIC_Cardiomegaly_AP_12206709.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8104_MIMIC_Cardiomegaly_AP_12277320.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8326_MIMIC_Cardiomegaly_AP_12340484.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8348_MIMIC_Cardiomegaly_AP_12350752.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8377_MIMIC_Cardiomegaly_AP_12356657.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8379_MIMIC_Cardiomegaly_AP_12356657.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8432_MIMIC_Cardiomegaly_AP_12364425.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8874_MIMIC_Cardiomegaly_AP_12499945.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9861_MIMIC_Cardiomegaly_AP_12809280.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10618_MIMIC_Cardiomegaly_AP_13063001.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10702_MIMIC_Cardiomegaly_AP_13090641.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11105_MIMIC_Cardiomegaly_AP_13215261.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12055_MIMIC_Cardiomegaly_AP_13489125.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13748_MIMIC_Cardiomegaly_AP_13989970.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13748_MIMIC_Cardiomegaly_AP_13989970.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15996_MIMIC_Cardiomegaly_AP_14689985.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18783_MIMIC_Cardiomegaly_AP_15438558.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/20064_MIMIC_Cardiomegaly_AP_15799760.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22003_MIMIC_Cardiomegaly_AP_16381668.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22236_MIMIC_Cardiomegaly_AP_16444272.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22342_MIMIC_Cardiomegaly_AP_16454913.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23228_MIMIC_Cardiomegaly_AP_16747881.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23667_MIMIC_Cardiomegaly_AP_16892349.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/25367_MIMIC_Cardiomegaly_AP_17396841.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/26483_MIMIC_Cardiomegaly_AP_17717614.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/26769_MIMIC_Cardiomegaly_AP_17818490.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/26769_MIMIC_Cardiomegaly_AP_17818490.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/28247_MIMIC_Cardiomegaly_AP_18264198.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/32368_MIMIC_Cardiomegaly_AP_19509940.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/32368_MIMIC_Cardiomegaly_AP_19509940.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/32368_MIMIC_Cardiomegaly_AP_19509940.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/32546_MIMIC_Cardiomegaly_AP_19557250.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/32630_MIMIC_Cardiomegaly_AP_19596157.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/32630_MIMIC_Cardiomegaly_AP_19596157.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/33265_MIMIC_Cardiomegaly_AP_19736957.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/33545_MIMIC_Cardiomegaly_AP_19811138.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/33719_MIMIC_Cardiomegaly_AP_19845120.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/33750_MIMIC_Cardiomegaly_AP_19855099.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/33750_MIMIC_Cardiomegaly_AP_19855099.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/33811_MIMIC_Cardiomegaly_AP_19865076.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/34123_MIMIC_Cardiomegaly_AP_19972172.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/34123_MIMIC_Cardiomegaly_AP_19972172.jpg
# /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/34210_MIMIC_Cardiomegaly_AP_19997367.jpg
# Copying files: 100%|██████████| 406/406 [00:00<00:00, 107309.06it/s]
# Files that encountered errors during the copy operation:
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2_MIMIC_Cardiomegaly_AP_10001884.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/133_MIMIC_Cardiomegaly_AP_10024982.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/167_MIMIC_Cardiomegaly_AP_10039272.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/213_MIMIC_Cardiomegaly_AP_10062020.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/234_MIMIC_Cardiomegaly_AP_10066209.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/247_MIMIC_Cardiomegaly_AP_10071403.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/260_MIMIC_Cardiomegaly_AP_10073847.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/329_MIMIC_Cardiomegaly_AP_10111075.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/367_MIMIC_Cardiomegaly_AP_10127469.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/422_MIMIC_Cardiomegaly_AP_10147087.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/704_MIMIC_Cardiomegaly_AP_10216556.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/900_MIMIC_Cardiomegaly_AP_10268877.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/927_MIMIC_Cardiomegaly_AP_10271367.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1176_MIMIC_Cardiomegaly_AP_10337761.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1182_MIMIC_Cardiomegaly_AP_10338508.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1251_MIMIC_Cardiomegaly_AP_10361837.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1269_MIMIC_Cardiomegaly_AP_10364180.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1535_MIMIC_Cardiomegaly_AP_10439781.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1566_MIMIC_Cardiomegaly_AP_10449408.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1583_MIMIC_Cardiomegaly_AP_10452634.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1589_MIMIC_Cardiomegaly_AP_10455192.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1627_MIMIC_Cardiomegaly_AP_10459005.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/1962_MIMIC_Cardiomegaly_AP_10559377.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2021_MIMIC_Cardiomegaly_AP_10577647.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2032_MIMIC_Cardiomegaly_AP_10580965.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2264_MIMIC_Cardiomegaly_AP_10650522.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2294_MIMIC_Cardiomegaly_AP_10659847, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2355_MIMIC_Cardiomegaly_AP_10670818.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2458_MIMIC_Cardiomegaly_AP_10712217.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2462_MIMIC_Cardiomegaly_AP_10712217.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2522_MIMIC_Cardiomegaly_AP_10723086.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2551_MIMIC_Cardiomegaly_AP_10737408.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2672_MIMIC_Cardiomegaly_AP_10790860.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2911_MIMIC_Cardiomegaly_AP_10867166.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2978_MIMIC_Cardiomegaly_AP_10896351.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/2984_MIMIC_Cardiomegaly_AP_10896351.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3023_MIMIC_Cardiomegaly_AP_10900387.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3121_MIMIC_Cardiomegaly_AP_10922531.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3138_MIMIC_Cardiomegaly_AP_10924768.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3225_MIMIC_Cardiomegaly_AP_10952678.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3348_MIMIC_Cardiomegaly_AP_10983866.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3381_MIMIC_Cardiomegaly_AP_10994222.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3536_MIMIC_Cardiomegaly_AP_11047741.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3556_MIMIC_Cardiomegaly_AP_11048381.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3559_MIMIC_Cardiomegaly_AP_11049412.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3623_MIMIC_Cardiomegaly_AP_11068484.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3873_MIMIC_Cardiomegaly_AP_11151295.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/3968_MIMIC_Cardiomegaly_AP_11173335.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4023_MIMIC_Cardiomegaly_AP_11185907.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4037_MIMIC_Cardiomegaly_AP_11194776.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4050_MIMIC_Cardiomegaly_AP_11201441.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4102_MIMIC_Cardiomegaly_AP_11209060.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4231_MIMIC_Cardiomegaly_AP_11244250.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4332_MIMIC_Cardiomegaly_AP_11269936, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4339_MIMIC_Cardiomegaly_AP_11271531.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4355_MIMIC_Cardiomegaly_AP_11276636.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4494_MIMIC_Cardiomegaly_AP_11313834.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4620_MIMIC_Cardiomegaly_AP_11343907.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4638_MIMIC_Cardiomegaly_AP_11345335.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4696_MIMIC_Cardiomegaly_AP_11363157.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4763_MIMIC_Cardiomegaly_AP_11390883.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4767_MIMIC_Cardiomegaly_AP_11392593.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4944_MIMIC_Cardiomegaly_AP_11441946.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/4985_MIMIC_Cardiomegaly_AP_11451979.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5004_MIMIC_Cardiomegaly_AP_11455001.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5023_MIMIC_Cardiomegaly_AP_11466215.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5103_MIMIC_Cardiomegaly_AP_11492213.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5239_MIMIC_Cardiomegaly_AP_11532890.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5300_MIMIC_Cardiomegaly_AP_11548762.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5329_MIMIC_Cardiomegaly_AP_11553956.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5452_MIMIC_Cardiomegaly_AP_11594102.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5677_MIMIC_Cardiomegaly_AP_11636169, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5677_MIMIC_Cardiomegaly_AP_11636169.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5699_MIMIC_Cardiomegaly_AP_11639762.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5723_MIMIC_Cardiomegaly_AP_11648170.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5820_MIMIC_Cardiomegaly_AP_11677206.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5828_MIMIC_Cardiomegaly_AP_11681010.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5858_MIMIC_Cardiomegaly_AP_11686707.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5880_MIMIC_Cardiomegaly_AP_11693603.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/5983_MIMIC_Cardiomegaly_AP_11722038.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6077_MIMIC_Cardiomegaly_AP_11750478.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6100_MIMIC_Cardiomegaly_AP_11752817.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6154_MIMIC_Cardiomegaly_AP_11770965.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6237_MIMIC_Cardiomegaly_AP_11798500.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6251_MIMIC_Cardiomegaly_AP_11801290.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6321_MIMIC_Cardiomegaly_AP_11817840.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6469_MIMIC_Cardiomegaly_AP_11861017.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6528_MIMIC_Cardiomegaly_AP_11867957.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6557_MIMIC_Cardiomegaly_AP_11880923.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6581_MIMIC_Cardiomegaly_AP_11888962.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6599_MIMIC_Cardiomegaly_AP_11892979.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6723_MIMIC_Cardiomegaly_AP_11920643.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/6882_MIMIC_Cardiomegaly_AP_11955380.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7009_MIMIC_Cardiomegaly_AP_11984647.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7083_MIMIC_Cardiomegaly_AP_12008689.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7096_MIMIC_Cardiomegaly_AP_12010510.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7111_MIMIC_Cardiomegaly_AP_12013634.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7116_MIMIC_Cardiomegaly_AP_12013634.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7146_MIMIC_Cardiomegaly_AP_12018901.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7175_MIMIC_Cardiomegaly_AP_12028465.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7248_MIMIC_Cardiomegaly_AP_12043836.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7278_MIMIC_Cardiomegaly_AP_12043836.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7318_MIMIC_Cardiomegaly_AP_12045761.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7390_MIMIC_Cardiomegaly_AP_12065121.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7468_MIMIC_Cardiomegaly_AP_12102463.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7588_MIMIC_Cardiomegaly_AP_12128253.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7590_MIMIC_Cardiomegaly_AP_12128253.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7616_MIMIC_Cardiomegaly_AP_12132246.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7619_MIMIC_Cardiomegaly_AP_12133655.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7650_MIMIC_Cardiomegaly_AP_12138413.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/7875_MIMIC_Cardiomegaly_AP_12206709.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8014_MIMIC_Cardiomegaly_AP_12242325.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8095_MIMIC_Cardiomegaly_AP_12274432.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8104_MIMIC_Cardiomegaly_AP_12277320.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8116_MIMIC_Cardiomegaly_AP_12283084.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8308_MIMIC_Cardiomegaly_AP_12338003.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8326_MIMIC_Cardiomegaly_AP_12340484.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8348_MIMIC_Cardiomegaly_AP_12350752.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8375_MIMIC_Cardiomegaly_AP_12356016.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8377_MIMIC_Cardiomegaly_AP_12356657.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8379_MIMIC_Cardiomegaly_AP_12356657.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8419_MIMIC_Cardiomegaly_AP_12363835.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8432_MIMIC_Cardiomegaly_AP_12364425.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8510_MIMIC_Cardiomegaly_AP_12382495.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8538_MIMIC_Cardiomegaly_AP_12388732.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8747_MIMIC_Cardiomegaly_AP_12450853.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8790_MIMIC_Cardiomegaly_AP_12462675.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8874_MIMIC_Cardiomegaly_AP_12499945.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/8931_MIMIC_Cardiomegaly_AP_12517870.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9016_MIMIC_Cardiomegaly_AP_12562737.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9107_MIMIC_Cardiomegaly_AP_12590816.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9155_MIMIC_Cardiomegaly_AP_12606543.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9193_MIMIC_Cardiomegaly_AP_12611156.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9497_MIMIC_Cardiomegaly_AP_12701519.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9615_MIMIC_Cardiomegaly_AP_12728628.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9694_MIMIC_Cardiomegaly_AP_12746489.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9804_MIMIC_Cardiomegaly_AP_12789116.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9839_MIMIC_Cardiomegaly_AP_12808249.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9861_MIMIC_Cardiomegaly_AP_12809280.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9873_MIMIC_Cardiomegaly_AP_12820120.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9906_MIMIC_Cardiomegaly_AP_12831242.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9929_MIMIC_Cardiomegaly_AP_12843379.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/9945_MIMIC_Cardiomegaly_AP_12850009.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10187_MIMIC_Cardiomegaly_AP_12935838.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10448_MIMIC_Cardiomegaly_AP_13018035.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10467_MIMIC_Cardiomegaly_AP_13021440.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10481_MIMIC_Cardiomegaly_AP_13024904.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10591_MIMIC_Cardiomegaly_AP_13058887.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10618_MIMIC_Cardiomegaly_AP_13063001.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10702_MIMIC_Cardiomegaly_AP_13090641.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10798_MIMIC_Cardiomegaly_AP_13120648.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/10939_MIMIC_Cardiomegaly_AP_13174810.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11054_MIMIC_Cardiomegaly_AP_13198693.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11071_MIMIC_Cardiomegaly_AP_13204105.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11095_MIMIC_Cardiomegaly_AP_13211234.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11105_MIMIC_Cardiomegaly_AP_13215261.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11163_MIMIC_Cardiomegaly_AP_13228941.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11306_MIMIC_Cardiomegaly_AP_13268981.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11438_MIMIC_Cardiomegaly_AP_13299285.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11508_MIMIC_Cardiomegaly_AP_13321760.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11536_MIMIC_Cardiomegaly_AP_13325402.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11597_MIMIC_Cardiomegaly_AP_13352605.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11604_MIMIC_Cardiomegaly_AP_13356071.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11850_MIMIC_Cardiomegaly_AP_13439409.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/11954_MIMIC_Cardiomegaly_AP_13473061.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12040_MIMIC_Cardiomegaly_AP_13488246.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12055_MIMIC_Cardiomegaly_AP_13489125.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12462_MIMIC_Cardiomegaly_AP_13607095.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12520_MIMIC_Cardiomegaly_AP_13633058.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12553_MIMIC_Cardiomegaly_AP_13645282.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12616_MIMIC_Cardiomegaly_AP_13658672.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12638_MIMIC_Cardiomegaly_AP_13663156.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12722_MIMIC_Cardiomegaly_AP_13693499.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12735_MIMIC_Cardiomegaly_AP_13696823.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12792_MIMIC_Cardiomegaly_AP_13712785.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/12830_MIMIC_Cardiomegaly_AP_13718173.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13066_MIMIC_Cardiomegaly_AP_13787816.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13174_MIMIC_Cardiomegaly_AP_13830137.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13193_MIMIC_Cardiomegaly_AP_13837390.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13493_MIMIC_Cardiomegaly_AP_13901345.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13497_MIMIC_Cardiomegaly_AP_13903940.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13702_MIMIC_Cardiomegaly_AP_13978244.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13704_MIMIC_Cardiomegaly_AP_13978368.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13748_MIMIC_Cardiomegaly_AP_13989970.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13845_MIMIC_Cardiomegaly_AP_14021217.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/13967_MIMIC_Cardiomegaly_AP_14057989.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14114_MIMIC_Cardiomegaly_AP_14092420.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14132_MIMIC_Cardiomegaly_AP_14093782.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14252_MIMIC_Cardiomegaly_AP_14130631.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14434_MIMIC_Cardiomegaly_AP_14174955.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14459_MIMIC_Cardiomegaly_AP_14175177.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14505_MIMIC_Cardiomegaly_AP_14186815.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14578_MIMIC_Cardiomegaly_AP_14201197.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14716_MIMIC_Cardiomegaly_AP_14246614.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14811_MIMIC_Cardiomegaly_AP_14280430.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14817_MIMIC_Cardiomegaly_AP_14280430.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/14901_MIMIC_Cardiomegaly_AP_14316200.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15054_MIMIC_Cardiomegaly_AP_14371035.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15180_MIMIC_Cardiomegaly_AP_14410396.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15292_MIMIC_Cardiomegaly_AP_14451001.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15440_MIMIC_Cardiomegaly_AP_14493762.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15654_MIMIC_Cardiomegaly_AP_14566882.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15663_MIMIC_Cardiomegaly_AP_14569206.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15751_MIMIC_Cardiomegaly_AP_14605415.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15837_MIMIC_Cardiomegaly_AP_14634306.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/15996_MIMIC_Cardiomegaly_AP_14689985.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16025_MIMIC_Cardiomegaly_AP_14691641.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16210_MIMIC_Cardiomegaly_AP_14744884.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16252_MIMIC_Cardiomegaly_AP_14760338.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16300_MIMIC_Cardiomegaly_AP_14774414.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16411_MIMIC_Cardiomegaly_AP_14805440.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16565_MIMIC_Cardiomegaly_AP_14851532.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16671_MIMIC_Cardiomegaly_AP_14873817.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16915_MIMIC_Cardiomegaly_AP_14953390.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/16969_MIMIC_Cardiomegaly_AP_14978865.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17057_MIMIC_Cardiomegaly_AP_15003038.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17098_MIMIC_Cardiomegaly_AP_15013830.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17112_MIMIC_Cardiomegaly_AP_15019807.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17447_MIMIC_Cardiomegaly_AP_15119590.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17483_MIMIC_Cardiomegaly_AP_15131736.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17496_MIMIC_Cardiomegaly_AP_15131736.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17521_MIMIC_Cardiomegaly_AP_15140256.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17558_MIMIC_Cardiomegaly_AP_15149227.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17743_MIMIC_Cardiomegaly_AP_15189222.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17800_MIMIC_Cardiomegaly_AP_15206209.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17803_MIMIC_Cardiomegaly_AP_15206209.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17870_MIMIC_Cardiomegaly_AP_15214825.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/17965_MIMIC_Cardiomegaly_AP_15237286.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18036_MIMIC_Cardiomegaly_AP_15257559.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18081_MIMIC_Cardiomegaly_AP_15264766, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18081_MIMIC_Cardiomegaly_AP_15264766.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18317_MIMIC_Cardiomegaly_AP_15321935.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18469_MIMIC_Cardiomegaly_AP_15355221.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18474_MIMIC_Cardiomegaly_AP_15355458.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18487_MIMIC_Cardiomegaly_AP_15357098.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18515_MIMIC_Cardiomegaly_AP_15368337.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18642_MIMIC_Cardiomegaly_AP_15396624, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18666_MIMIC_Cardiomegaly_AP_15403852.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18783_MIMIC_Cardiomegaly_AP_15438558.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18787_MIMIC_Cardiomegaly_AP_15439881.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/18932_MIMIC_Cardiomegaly_AP_15479539.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19025_MIMIC_Cardiomegaly_AP_15506615.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19093_MIMIC_Cardiomegaly_AP_15527518.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19098_MIMIC_Cardiomegaly_AP_15529225.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19231_MIMIC_Cardiomegaly_AP_15563657.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19326_MIMIC_Cardiomegaly_AP_15574754.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19408_MIMIC_Cardiomegaly_AP_15614063.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19577_MIMIC_Cardiomegaly_AP_15656571.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19597_MIMIC_Cardiomegaly_AP_15665863.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19763_MIMIC_Cardiomegaly_AP_15704322.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/19828_MIMIC_Cardiomegaly_AP_15738526.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/20064_MIMIC_Cardiomegaly_AP_15799760.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/20082_MIMIC_Cardiomegaly_AP_15809646.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/20473_MIMIC_Cardiomegaly_AP_15913953.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/20604_MIMIC_Cardiomegaly_AP_15944907.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21094_MIMIC_Cardiomegaly_AP_16096060.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21355_MIMIC_Cardiomegaly_AP_16187793.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21452_MIMIC_Cardiomegaly_AP_16209892.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21468_MIMIC_Cardiomegaly_AP_16225290.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21531_MIMIC_Cardiomegaly_AP_16239546.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21642_MIMIC_Cardiomegaly_AP_16276628.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21653_MIMIC_Cardiomegaly_AP_16278588.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21712_MIMIC_Cardiomegaly_AP_16293344.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21736_MIMIC_Cardiomegaly_AP_16298810.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21764_MIMIC_Cardiomegaly_AP_16308768.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21786_MIMIC_Cardiomegaly_AP_16311983.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21925_MIMIC_Cardiomegaly_AP_16345504.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/21980_MIMIC_Cardiomegaly_AP_16366110.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22003_MIMIC_Cardiomegaly_AP_16381668.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22236_MIMIC_Cardiomegaly_AP_16444272.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22339_MIMIC_Cardiomegaly_AP_16454913.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22342_MIMIC_Cardiomegaly_AP_16454913.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22591_MIMIC_Cardiomegaly_AP_16533299.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22604_MIMIC_Cardiomegaly_AP_16542986.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22718_MIMIC_Cardiomegaly_AP_16581134.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22724_MIMIC_Cardiomegaly_AP_16582727.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22742_MIMIC_Cardiomegaly_AP_16595729.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22886_MIMIC_Cardiomegaly_AP_16652205.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/22997_MIMIC_Cardiomegaly_AP_16686301.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23029_MIMIC_Cardiomegaly_AP_16697275.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23228_MIMIC_Cardiomegaly_AP_16747881.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23327_MIMIC_Cardiomegaly_AP_16773335.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23345_MIMIC_Cardiomegaly_AP_16776336.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23368_MIMIC_Cardiomegaly_AP_16783577.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23448_MIMIC_Cardiomegaly_AP_16796985.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23485_MIMIC_Cardiomegaly_AP_16805731.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23507_MIMIC_Cardiomegaly_AP_16817701.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23667_MIMIC_Cardiomegaly_AP_16892349.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/23999_MIMIC_Cardiomegaly_AP_16995942.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24242_MIMIC_Cardiomegaly_AP_17080143.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24247_MIMIC_Cardiomegaly_AP_17086932.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24268_MIMIC_Cardiomegaly_AP_17094735.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24423_MIMIC_Cardiomegaly_AP_17132849.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24575_MIMIC_Cardiomegaly_AP_17172702.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24685_MIMIC_Cardiomegaly_AP_17211008.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24832_MIMIC_Cardiomegaly_AP_17256683.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/Cardiomegaly/AP/24874_MIMIC_Cardiomegaly_AP_17261065.jpg, Error: File already exists in destination.
# ...
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/14847_MIMIC_No-Finding_AP_16498330.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/14862_MIMIC_No-Finding_AP_16511964.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15149_MIMIC_No-Finding_AP_16662316.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15153_MIMIC_No-Finding_AP_16662316.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15225_MIMIC_No-Finding_AP_16701863.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15267_MIMIC_No-Finding_AP_16720612.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15280_MIMIC_No-Finding_AP_16724979.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15461_MIMIC_No-Finding_AP_16810756.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15516_MIMIC_No-Finding_AP_16841586.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15616_MIMIC_No-Finding_AP_16892349.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15642_MIMIC_No-Finding_AP_16897045.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15653_MIMIC_No-Finding_AP_16897045.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15689_MIMIC_No-Finding_AP_16912036.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15721_MIMIC_No-Finding_AP_16921511.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/15975_MIMIC_No-Finding_AP_17019564.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16028_MIMIC_No-Finding_AP_17053123.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16151_MIMIC_No-Finding_AP_17096041.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16302_MIMIC_No-Finding_AP_17167982.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16429_MIMIC_No-Finding_AP_17219004.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16481_MIMIC_No-Finding_AP_17244595.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16483_MIMIC_No-Finding_AP_17244595.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16538_MIMIC_No-Finding_AP_17261183.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16677_MIMIC_No-Finding_AP_17328406.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16695_MIMIC_No-Finding_AP_17336353.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16746_MIMIC_No-Finding_AP_17349939.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16770_MIMIC_No-Finding_AP_17361324.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16802_MIMIC_No-Finding_AP_17377831.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16809_MIMIC_No-Finding_AP_17382794.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16816_MIMIC_No-Finding_AP_17391196.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16860_MIMIC_No-Finding_AP_17413521.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16929_MIMIC_No-Finding_AP_17439447.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/16979_MIMIC_No-Finding_AP_17455506.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17008_MIMIC_No-Finding_AP_17469778.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17050_MIMIC_No-Finding_AP_17477304.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17154_MIMIC_No-Finding_AP_17521562.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17215_MIMIC_No-Finding_AP_17549814.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17270_MIMIC_No-Finding_AP_17571227.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17352_MIMIC_No-Finding_AP_17600374.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17385_MIMIC_No-Finding_AP_17610678.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17433_MIMIC_No-Finding_AP_17637743.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17533_MIMIC_No-Finding_AP_17678188.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17549_MIMIC_No-Finding_AP_17688364.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17585_MIMIC_No-Finding_AP_17711415.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17649_MIMIC_No-Finding_AP_17744732.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17673_MIMIC_No-Finding_AP_17760190.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17758_MIMIC_No-Finding_AP_17799996.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17795_MIMIC_No-Finding_AP_17816525.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17829_MIMIC_No-Finding_AP_17839341.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17882_MIMIC_No-Finding_AP_17872769.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/17937_MIMIC_No-Finding_AP_17898039.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18021_MIMIC_No-Finding_AP_17935897.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18046_MIMIC_No-Finding_AP_17945455.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18067_MIMIC_No-Finding_AP_17957742.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18125_MIMIC_No-Finding_AP_17973921.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18188_MIMIC_No-Finding_AP_18002994.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18364_MIMIC_No-Finding_AP_18079481.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18447_MIMIC_No-Finding_AP_18111516.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18467_MIMIC_No-Finding_AP_18118295.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18590_MIMIC_No-Finding_AP_18169660.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18602_MIMIC_No-Finding_AP_18171850.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18617_MIMIC_No-Finding_AP_18179234.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18689_MIMIC_No-Finding_AP_18218394.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18695_MIMIC_No-Finding_AP_18223363.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18772_MIMIC_No-Finding_AP_18256282.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18822_MIMIC_No-Finding_AP_18270774.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18937_MIMIC_No-Finding_AP_18315784.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/18957_MIMIC_No-Finding_AP_18321272.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19026_MIMIC_No-Finding_AP_18348666.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19131_MIMIC_No-Finding_AP_18402151.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19197_MIMIC_No-Finding_AP_18429092.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19232_MIMIC_No-Finding_AP_18448597.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19272_MIMIC_No-Finding_AP_18470053.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19340_MIMIC_No-Finding_AP_18505859.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19668_MIMIC_No-Finding_AP_18655830.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19717_MIMIC_No-Finding_AP_18666022.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19758_MIMIC_No-Finding_AP_18687658.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19783_MIMIC_No-Finding_AP_18695475.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19826_MIMIC_No-Finding_AP_18712598.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/19938_MIMIC_No-Finding_AP_18757749.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20023_MIMIC_No-Finding_AP_18797768.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20111_MIMIC_No-Finding_AP_18845699.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20176_MIMIC_No-Finding_AP_18865478.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20241_MIMIC_No-Finding_AP_18887370.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20409_MIMIC_No-Finding_AP_18956477.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20602_MIMIC_No-Finding_AP_19020115.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20615_MIMIC_No-Finding_AP_19022280.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20785_MIMIC_No-Finding_AP_19111424.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20861_MIMIC_No-Finding_AP_19135819.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/20898_MIMIC_No-Finding_AP_19155768.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21034_MIMIC_No-Finding_AP_19236260.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21068_MIMIC_No-Finding_AP_19245405.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21165_MIMIC_No-Finding_AP_19279007.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21240_MIMIC_No-Finding_AP_19317770.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21264_MIMIC_No-Finding_AP_19326866.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21310_MIMIC_No-Finding_AP_19348612.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21354_MIMIC_No-Finding_AP_19369607.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21460_MIMIC_No-Finding_AP_19416768.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21508_MIMIC_No-Finding_AP_19449400.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21573_MIMIC_No-Finding_AP_19477853.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21576_MIMIC_No-Finding_AP_19480277.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21845_MIMIC_No-Finding_AP_19604041.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/21942_MIMIC_No-Finding_AP_19638656.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22014_MIMIC_No-Finding_AP_19661672.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22057_MIMIC_No-Finding_AP_19682346.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22101_MIMIC_No-Finding_AP_19698926.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22123_MIMIC_No-Finding_AP_19706109.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22172_MIMIC_No-Finding_AP_19735459.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22245_MIMIC_No-Finding_AP_19761472.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22262_MIMIC_No-Finding_AP_19768190.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22309_MIMIC_No-Finding_AP_19780620.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22367_MIMIC_No-Finding_AP_19809456.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22384_MIMIC_No-Finding_AP_19810220.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22577_MIMIC_No-Finding_AP_19881629.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22580_MIMIC_No-Finding_AP_19882171.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22750_MIMIC_No-Finding_AP_19962250.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22804_MIMIC_No-Finding_AP_19991135.jpg, Error: File already exists in destination.
# File: /ssd2/averijordan/datasets/MIMIC/No-Finding/AP/22816_MIMIC_No-Finding_AP_19997367.jpg, Error: File already exists in destination.

# %% [markdown]
# Make sure the file names are correct here if you reuse this code
